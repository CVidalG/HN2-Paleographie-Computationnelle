# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt')

# %%
results = model('/Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_05.jpg', save=True)
# Out:
# image 1/1 /Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_05.jpg: 416x640 1 person, 8 cows, 75.6ms
# Speed: 6.4ms preprocess, 75.6ms inference, 9.2ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /Users/nostradamus/Desktop/runs/detect/predict

# %%
model = YOLO('yolov8m-worldv2.pt')

# %%
model.set_classes(['horse in water'])

results = model('/Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_05.jpg', save=True)
# Out:
# image 1/1 /Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_05.jpg: 416x640 14 horse in waters, 181.7ms
# Speed: 2.2ms preprocess, 181.7ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /Users/nostradamus/Desktop/runs/detect/predict4

# %%
from ultralytics import FastSAM

# %%
model = FastSAM('FastSAM-s.pt')

# %%
results = model('/Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_05.jpg', save=True, show_labels=False)
# Out:
# image 1/1 /Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_05.jpg: 416x640 43 objects, 171.6ms
# Speed: 3.1ms preprocess, 171.6ms inference, 19.7ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /Users/nostradamus/Desktop/runs/segment/predict

# %%
results = model('/Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_20.jpg', save=True, show_labels=False,
                texts='horse')
# Out:
# image 1/1 /Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_20.jpg: 480x640 1 object, 142.9ms
# Speed: 2.1ms preprocess, 142.9ms inference, 584.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /Users/nostradamus/Desktop/runs/segment/predict

# %%
from ultralytics import ASSETS, SAM, YOLO, FastSAM

# %%
model = SAM('mobile_sam.pt')

# %%
model.predict("/Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_20.jpg", save=True, device='mps')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 model.predict("/Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Giuseppe_Castiglione_20.jpg", save=True, device='mps')
#
# File ~/miniconda3/envs/yolo/lib/python3.9/site-packages/ultralytics/models/sam/model.py:109, in SAM.predict(self, source, stream, bboxes, points, labels, **kwargs)
#     107 kwargs = {**overrides, **kwargs}
#     108 prompts = dict(bboxes=bboxes, points=points, labels=labels)
# --> 109 return super().predict(source, stream, prompts=prompts, **kwargs)
#
# File ~/miniconda3/envs/yolo/lib/python3.9/site-packages/ultralytics/engine/model.py:536, in Model.predict(self, source, stream, predictor, **kwargs)
# ...

# %%
from ultralytics import YOLOE

# %%
model = YOLOE("yoloe-26s-seg.pt")

# %%
model.set_classes(['person in red '])
model.predict("/Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Qiu_Ying_09.jpg", save=True, conf=0.7)
# Out:
# image 1/1 /Users/nostradamus/Documents/Chartes/Cours_ENC/Github/HN2-Paleographie-Computationnelle/lesson2-enluminures/Data/DataBnFSegmentation2019/MiradorAnnotations/images/Qiu_Ying_09.jpg: 640x384 (no detections), 182.4ms
# Speed: 2.0ms preprocess, 182.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to /Users/nostradamus/Desktop/runs/segment/predict4
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: ['person in red ']
#  obb: None
#  orig_img: array([[[ 92, 140, 188],
#          [103, 151, 199],
#          [117, 166, 212],
#          ...,
#          [123, 170, 208],
#          [115, 164, 204],
#          [107, 156, 196]],
#
#         [[110, 158, 206],
#          [ 99, 147, 195],
#          [102, 151, 197],
#          ...,
#          [124, 171, 209],
#          [117, 166, 206],
#          [110, 159, 199]],
#
#         [[107, 157, 203],
# ...
